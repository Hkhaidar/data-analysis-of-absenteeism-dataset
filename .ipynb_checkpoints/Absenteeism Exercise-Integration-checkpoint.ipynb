# %%
from absenteeism_modules import*
model=absenteeism_model('model','scaler')
model.load_and_clean_data('Absenteeism_data.csv')
model.predicted_outputs()
# Out:
# C:\Users\hkhai\OneDrive\Desktop\python+tableau+sql\absenteeism_modules.py:31: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   X_scaled = pd.DataFrame(self.scaler.transform(X[self.columns]), columns=self.columns)
#      Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0           0         0         0         1            7
# 1           0         0         0         0            7
# 2           0         0         0         1            7
# 3           1         0         0         0            7
# 4           0         0         0         1            7
# 5           0         0         0         1            7
# 6           0         0         0         1            7
# 7           0         0         0         1            7
# 8           0         0         1         0            7
# 9           0         0         0         1            7
# 10          1         0         0         0            7
# ...

# %%
#pd.read_csv('Absenteeism_data.csv')
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 0    11                  26  07/07/2015                     289
# 1    36                   0  14/07/2015                     118
# 2     3                  23  15/07/2015                     179
# 3     7                   7  16/07/2015                     279
# 4    11                  23  23/07/2015                     289
# 5     3                  23  10/07/2015                     179
# 6    10                  22  17/07/2015                     361
# 7    20                  23  24/07/2015                     260
# 8    14                  19  06/07/2015                     155
# 9     1                  22  13/07/2015                     235
# 10   20                   1  20/07/2015                     260
# 11   20                   1  14/07/2015                     260
# 12   20                  11  15/07/2015                     260
# 13    3                  11  15/07/2015                     179
# ...

# %%
# Out:
# C:\Users\hkhai\OneDrive\Desktop\python+tableau+sql\absenteeism_modules.py:31: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   X_scaled = pd.DataFrame(self.scaler.transform(X[self.columns]), columns=self.columns)

# %%
# Out:
#      Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0           0         0         0         1            7
# 1           0         0         0         0            7
# 2           0         0         0         1            7
# 3           1         0         0         0            7
# 4           0         0         0         1            7
# 5           0         0         0         1            7
# 6           0         0         0         1            7
# 7           0         0         0         1            7
# 8           0         0         1         0            7
# 9           0         0         0         1            7
# 10          1         0         0         0            7
# 11          1         0         0         0            7
# 12          1         0         0         0            7
# 13          1         0         0         0            7
# 14          0         0         0         1            7
# ...
